# %% [markdown]
# # [模块名称] (如：Rotary Position Embedding)
#
# > 源码对应：[`core/path/to/module.py`](../core/path/to/module.py)
#
# 本笔记本旨在拆解【模块名称】的核心原理和具体实现。

# %% [markdown]
# ## 1. 核心动机与数学原理
#
# *解释为什么需要这个模块，它解决了什么问题。*
#
# ### 公式描述
# $$
# y = f(x)
# $$

# %% [markdown]
# ## 2. 代码实现解析
#
# *详细说明源码中的关键实现细节。可以利用 Markdown 链接直接跳转到 `core/` 目录下的具体代码行，例如：[`forward` 方法实现](../core/path/to/module.py#L42)。*

# %% [markdown]
# # 3. 交互式演示
# # 在这里引入源码模块并进行 Tensors 的前向传播测试与打印
#
# import torch
# import sys
# sys.path.append('..')
#
# # from core.path.to.module import Module
#
# # 示例数据
# # x = torch.randn(1, 4, 8)
# # m = Module()
# # out = m(x)
# # print("Output shape:", out.shape)

# %% [markdown]
# ## 4. 与前代技术的对比
#
# | 特性 | 前代方案 | 本模块 |
# | --- | --- | --- |
# | **[维度]** | ... | ... |
# | **[耗时]** | ... | ... |
#
# ---

# %% [markdown]
# ## 5. 延伸阅读与参考资料
#
# - **核心论文 (Paper)**: [Paper Title]
# - **优质资源 (Blog/Code)**: [Link Title](url)
